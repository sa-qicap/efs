# %%
import pandas as pd

# %%
df = pd.read_csv('/efs/sameer.arora/logs/IndexParamSim/config_3/around_worst_time.csv')
df
# Out:
#       Unnamed: 0                    log_time log_level        contract  \
# 0              1  2024-08-29 15:24:54.999727      INFO         NSE_ABB
# 1              2  2024-08-29 15:24:54.999727      INFO  NSE_ABBOTINDIA
# 2              3  2024-08-29 15:24:54.999727      INFO   NSE_ABCAPITAL
# 3              4  2024-08-29 15:24:54.999727      INFO       NSE_ABFRL
# 4              5  2024-08-29 15:24:54.999727      INFO         NSE_ACC
# ...          ...                         ...       ...             ...
# 6721        6722  2024-08-29 15:27:59.999727      INFO         NSE_UPL
# 6722        6723  2024-08-29 15:27:59.999727      INFO        NSE_VEDL
# 6723        6724  2024-08-29 15:27:59.999727      INFO      NSE_VOLTAS
# 6724        6725  2024-08-29 15:27:59.999727      INFO       NSE_WIPRO
# 6725        6726  2024-08-29 15:27:59.999727      INFO   NSE_ZYDUSLIFE
#
#           mid    weight  is_constituent  vol_ratio  vol_ratio_index  \
# 0         0.0  0.000000              -1   0.000000         0.006337
# 1         0.0  0.000000              -1   0.000000         0.006337
# 2         0.0  0.000000              -1   0.000000         0.006337
# 3         0.0  0.000000              -1   0.000000         0.006337
# 4         0.0  0.000000              -1   0.000000         0.006337
# ...       ...       ...             ...        ...              ...
# 6721      0.0  0.000000              -1   0.000000         0.015327
# 6722      0.0  0.000000              -1   0.000000         0.015327
# 6723      0.0  0.000000              -1   0.000000         0.015327
# 6724  54005.0  0.319495               1   0.008701         0.015327
# 6725      0.0  0.000000              -1   0.000000         0.015327
#
#       vol_ratio_constituents  ...  return.30000  return.60000  return.300000  \
# 0                   0.007596  ...       -0.0693       -0.0418         0.1309
# 1                   0.007596  ...        0.0166        0.0163        -0.0022
# 2                   0.007596  ...        0.0683        0.0137         0.1434
# 3                   0.007596  ...        0.0963        0.1204         0.2809
# 4                   0.007596  ...        0.0847        0.0119         0.3432
# ...                      ...  ...           ...           ...            ...
# 6721                0.007785  ...        0.0218        0.1350         0.1045
# 6722                0.007785  ...       -0.0054        0.0379         0.3084
# 6723                0.007785  ...        0.0042        0.1087         0.3220
# 6724                0.007785  ...       -0.0417        0.1021        -0.0139
# 6725                0.007785  ...        0.0399        0.1087         0.0931
#
#       return.600000  return.900000  return.1800000  time_only   date_only  \
# 0            0.4808         0.4760          0.7407   15:24:54  2024-08-29
# 1            0.0401         0.0089         -0.4414   15:24:54  2024-08-29
# 2            0.5350         0.2732          0.8469   15:24:54  2024-08-29
# 3            0.5939         0.3531          0.8186   15:24:54  2024-08-29
# 4            0.4626         0.3540          0.3247   15:24:54  2024-08-29
# ...             ...            ...             ...        ...         ...
# 6721         0.0958         0.1742          1.0539   15:27:59  2024-08-29
# 6722         0.2489         0.2056          0.2056   15:27:59  2024-08-29
# 6723         0.6256         0.8361          2.3938   15:27:59  2024-08-29
# 6724        -0.0232        -0.1299         -0.0742   15:27:59  2024-08-29
# 6725         0.1929         0.3947          0.5366   15:27:59  2024-08-29
#
#       lead_flag  lead_flag_vol
# 0             1             -1
# 1             1             -1
# 2             1             -1
# 3             1             -1
# 4             1             -1
# ...         ...            ...
# 6721          1              1
# 6722          1              1
# 6723          1              1
# 6724          1              1
# 6725          1              1
#
# [6726 rows x 32 columns]

# %%
df['r_ema'] = df['r'] - df['ratio_diff']
df['x'] = df['fi'] / df['fc']
df
# Out:
#       Unnamed: 0                    log_time log_level        contract  \
# 0              1  2024-08-29 15:24:54.999727      INFO         NSE_ABB
# 1              2  2024-08-29 15:24:54.999727      INFO  NSE_ABBOTINDIA
# 2              3  2024-08-29 15:24:54.999727      INFO   NSE_ABCAPITAL
# 3              4  2024-08-29 15:24:54.999727      INFO       NSE_ABFRL
# 4              5  2024-08-29 15:24:54.999727      INFO         NSE_ACC
# ...          ...                         ...       ...             ...
# 6721        6722  2024-08-29 15:27:59.999727      INFO         NSE_UPL
# 6722        6723  2024-08-29 15:27:59.999727      INFO        NSE_VEDL
# 6723        6724  2024-08-29 15:27:59.999727      INFO      NSE_VOLTAS
# 6724        6725  2024-08-29 15:27:59.999727      INFO       NSE_WIPRO
# 6725        6726  2024-08-29 15:27:59.999727      INFO   NSE_ZYDUSLIFE
#
#           mid    weight  is_constituent  vol_ratio  vol_ratio_index  \
# 0         0.0  0.000000              -1   0.000000         0.006337
# 1         0.0  0.000000              -1   0.000000         0.006337
# 2         0.0  0.000000              -1   0.000000         0.006337
# 3         0.0  0.000000              -1   0.000000         0.006337
# 4         0.0  0.000000              -1   0.000000         0.006337
# ...       ...       ...             ...        ...              ...
# 6721      0.0  0.000000              -1   0.000000         0.015327
# 6722      0.0  0.000000              -1   0.000000         0.015327
# 6723      0.0  0.000000              -1   0.000000         0.015327
# 6724  54005.0  0.319495               1   0.008701         0.015327
# 6725      0.0  0.000000              -1   0.000000         0.015327
#
#       vol_ratio_constituents  ...  return.300000  return.600000  \
# 0                   0.007596  ...         0.1309         0.4808
# 1                   0.007596  ...        -0.0022         0.0401
# 2                   0.007596  ...         0.1434         0.5350
# 3                   0.007596  ...         0.2809         0.5939
# 4                   0.007596  ...         0.3432         0.4626
# ...                      ...  ...            ...            ...
# 6721                0.007785  ...         0.1045         0.0958
# 6722                0.007785  ...         0.3084         0.2489
# 6723                0.007785  ...         0.3220         0.6256
# 6724                0.007785  ...        -0.0139        -0.0232
# 6725                0.007785  ...         0.0931         0.1929
#
#       return.900000  return.1800000  time_only   date_only  lead_flag  \
# 0            0.4760          0.7407   15:24:54  2024-08-29          1
# 1            0.0089         -0.4414   15:24:54  2024-08-29          1
# 2            0.2732          0.8469   15:24:54  2024-08-29          1
# 3            0.3531          0.8186   15:24:54  2024-08-29          1
# 4            0.3540          0.3247   15:24:54  2024-08-29          1
# ...             ...             ...        ...         ...        ...
# 6721         0.1742          1.0539   15:27:59  2024-08-29          1
# 6722         0.2056          0.2056   15:27:59  2024-08-29          1
# 6723         0.8361          2.3938   15:27:59  2024-08-29          1
# 6724        -0.1299         -0.0742   15:27:59  2024-08-29          1
# 6725         0.3947          0.5366   15:27:59  2024-08-29          1
#
#       lead_flag_vol     r_ema         x
# 0                -1  1.000291  1.001734
# 1                -1  1.000291  1.001734
# 2                -1  1.000291  1.001734
# 3                -1  1.000291  1.001734
# 4                -1  1.000291  1.001734
# ...             ...       ...       ...
# 6721              1  1.000743  1.001572
# 6722              1  1.000743  1.001572
# 6723              1  1.000743  1.001572
# 6724              1  1.000743  1.001572
# 6725              1  1.000743  1.001572
#
# [6726 rows x 34 columns]

# %%
# get rows with contract == NSE_ABB
a = df[df['contract'] == 'NSE_ABB']

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime



def plot_alpha(a, alpha_name, mid):
    # Function to convert log_time string to a datetime object, ignoring extra fractional digits
    def convert_log_time(log_time_str):
        # Check if log_time is already a datetime object
        if isinstance(log_time_str, datetime):
            return log_time_str  # Return as-is if already in the correct format
        else:
            log_time_str = log_time_str[:26]  # Truncate to remove extra digits
            return datetime.strptime(log_time_str, '%Y-%m-%d %H:%M:%S.%f')

    # Apply the conversion to the log_time column
    a['log_time'] = a['log_time'].apply(convert_log_time)

    # Create a figure and axis
    fig, ax1 = plt.subplots(figsize=(14, 7))

    # Plot the alpha values as a bar chart on the left y-axis
    colors = ['green' if alpha >= 0 else 'red' for alpha in a[alpha_name]]
    # colors2 = []
    # for r in a.iterrows():
    #     if r[1]['time_only'] == '15:26:54':
    #         colors2 += ['purple']
    #     elif r[1]['ratio_diff'] > 0:
    #         colors2 += ['green']
    #     else:
    #         colors2 += ['red']
        
    ax1.bar(a['log_time'], a[alpha_name], color=colors, width=0.00001, label='Alpha')

    # Label for the left y-axis (Alpha)
    ax1.set_ylabel('Alpha')

    # Create a second y-axis for the mid prices
    ax2 = ax1.twinx()

    # Plot the mid prices as a line chart on the right y-axis
    ax2.plot(a['log_time'], a[mid], color='blue', label='Mid Price', linewidth=1.5)

    # Label for the right y-axis (Mid Prices)
    ax2.set_ylabel('Mid Price')


    # Formatting the x-axis for better time visibility
    ax1.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

    plt.xticks(rotation=45)

    # Add a title and make the layout tighter
    plt.title('Alpha and Mid Price Over Time')
    fig.tight_layout()

    # Show the plot
    plt.show()

# %%
plot_alpha(a, 'ratio_diff', 'fi')
# Out:
# /home/sameer.arora/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig, ax1 = plt.subplots()

# Plot `fc` on the first y-axis
ax1.plot(a['log_time'], a['x'], color='blue', label='fc')
ax1.plot(a['log_time'], a['r_ema'], color='red', label='fi')
ax1.set_xlabel('Log Time')
ax1.set_ylabel('r', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create a second y-axis for `fi`
# ax2 = ax1.twinx()
# ax2.plot(a['log_time'], a['r_ema'], color='red', label='fi')
# ax2.set_ylabel('r_ema', color='red')
# ax2.tick_params(axis='y', labelcolor='red')

fig.tight_layout()
plt.show()

# %%
 u = pd.read_csv('/efs/sameer.arora/logs/IndexParamSim/config_3/around_worst_time_u.csv')
u
# Out:
#      Unnamed: 0                    log_time log_level        contract  \
# 0             1  2024-08-29 15:23:49.999727      INFO         NSE_ABB
# 1             2  2024-08-29 15:23:49.999727      INFO  NSE_ABBOTINDIA
# 2             3  2024-08-29 15:23:49.999727      INFO   NSE_ABCAPITAL
# 3             4  2024-08-29 15:23:49.999727      INFO       NSE_ABFRL
# 4             5  2024-08-29 15:23:49.999727      INFO         NSE_ACC
# ..          ...                         ...       ...             ...
# 703         704  2024-08-29 15:26:54.999727      INFO         NSE_UPL
# 704         705  2024-08-29 15:26:54.999727      INFO        NSE_VEDL
# 705         706  2024-08-29 15:26:54.999727      INFO      NSE_VOLTAS
# 706         707  2024-08-29 15:26:54.999727      INFO       NSE_WIPRO
# 707         708  2024-08-29 15:26:54.999727      INFO   NSE_ZYDUSLIFE
#
#          mid    weight  is_constituent  vol_ratio  vol_ratio_index  \
# 0        0.0  0.000000              -1   0.000000         0.039607
# 1        0.0  0.000000              -1   0.000000         0.039607
# 2        0.0  0.000000              -1   0.000000         0.039607
# 3        0.0  0.000000              -1   0.000000         0.039607
# 4        0.0  0.000000              -1   0.000000         0.039607
# ..       ...       ...             ...        ...              ...
# 703      0.0  0.000000              -1   0.000000         0.017522
# 704      0.0  0.000000              -1   0.000000         0.017522
# 705      0.0  0.000000              -1   0.000000         0.017522
# 706  54082.5  0.319495               1   0.008279         0.017522
# 707      0.0  0.000000              -1   0.000000         0.017522
#
#      vol_ratio_constituents  ...  return.10000  return.30000  return.60000  \
# 0                  0.020531  ...        0.0205        0.0230        0.0914
# 1                  0.020531  ...        0.0000        0.0000        0.0498
# 2                  0.020531  ...        0.0319        0.0820        0.0273
# 3                  0.020531  ...       -0.0080        0.0080        0.2172
# 4                  0.020531  ...        0.0794        0.1544        0.1207
# ..                      ...  ...           ...           ...           ...
# 703                0.010578  ...       -0.0174        0.0131       -0.0696
# 704                0.010578  ...        0.0650        0.1354        0.1409
# 705                0.010578  ...        0.0367        0.0876        0.0622
# 706                0.010578  ...        0.0463       -0.1667       -0.1575
# 707                0.010578  ...        0.0044        0.0022        0.0222
#
#      return.300000  return.600000  return.900000  return.1800000  time_only  \
# 0           0.1620         0.5420         0.5318          0.7872   15:23:49
# 1           0.0446         0.1588         0.0338         -0.1935   15:23:49
# 2           0.1139         0.5239         0.3075          0.9135   15:23:49
# 3           0.4264         0.8850         0.6758          1.0539   15:23:49
# 4           0.3339         0.5797         0.4807          0.5003   15:23:49
# ..             ...            ...            ...             ...        ...
# 703        -0.0044         0.0653         0.1175          0.9269   15:26:54
# 704         0.4930         0.4442         0.3196          0.4334   15:26:54
# 705         0.4056         0.6190         0.9270          1.7552   15:26:54
# 706        -0.0278        -0.1760        -0.2501         -0.2177   15:26:54
# 707         0.1796         0.0998         0.2572          0.4568   15:26:54
#
#       date_only  lead_flag
# 0    2024-08-29          1
# 1    2024-08-29          1
# 2    2024-08-29          1
# 3    2024-08-29          1
# 4    2024-08-29          1
# ..          ...        ...
# 703  2024-08-29          1
# 704  2024-08-29          1
# 705  2024-08-29          1
# 706  2024-08-29          1
# 707  2024-08-29          1
#
# [708 rows x 31 columns]

# %%
a2 = u[u['contract'] == 'NSE_ABB']
a2
# Out:
#      Unnamed: 0                    log_time log_level contract  mid  weight  \
# 0             1  2024-08-29 15:23:49.999727      INFO  NSE_ABB  0.0     0.0
# 177         178  2024-08-29 15:25:24.999727      INFO  NSE_ABB  0.0     0.0
# 354         355  2024-08-29 15:25:29.999727      INFO  NSE_ABB  0.0     0.0
# 531         532  2024-08-29 15:26:54.999727      INFO  NSE_ABB  0.0     0.0
#
#      is_constituent  vol_ratio  vol_ratio_index  vol_ratio_constituents  ...  \
# 0                -1        0.0         0.039607                0.020531  ...
# 177              -1        0.0         0.040099                0.019248  ...
# 354              -1        0.0         0.028282                0.015251  ...
# 531              -1        0.0         0.017522                0.010578  ...
#
#      return.10000  return.30000  return.60000  return.300000  return.600000  \
# 0          0.0205        0.0230        0.0914         0.1620         0.5420
# 177        0.0278        0.0275        0.0134         0.3070         0.5502
# 354        0.0109        0.0157       -0.0278         0.2913         0.4517
# 531       -0.0051        0.0885        0.0291         0.3207         0.4427
#
#      return.900000  return.1800000  time_only   date_only  lead_flag
# 0           0.5318          0.7872   15:23:49  2024-08-29          1
# 177         0.5380          0.8412   15:25:24  2024-08-29          1
# 354         0.4865          0.8296   15:25:29  2024-08-29          1
# 531         0.5063          0.7794   15:26:54  2024-08-29          1
#
# [4 rows x 31 columns]

# %%
plot_alpha(a2, 'ratio_diff', 'fi')
# Out:
# /home/sameer.arora/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
u
# Out:
#      Unnamed: 0                    log_time log_level        contract  \
# 0             1  2024-08-29 15:23:49.999727      INFO         NSE_ABB
# 1             2  2024-08-29 15:23:49.999727      INFO  NSE_ABBOTINDIA
# 2             3  2024-08-29 15:23:49.999727      INFO   NSE_ABCAPITAL
# 3             4  2024-08-29 15:23:49.999727      INFO       NSE_ABFRL
# 4             5  2024-08-29 15:23:49.999727      INFO         NSE_ACC
# ..          ...                         ...       ...             ...
# 703         704  2024-08-29 15:26:54.999727      INFO         NSE_UPL
# 704         705  2024-08-29 15:26:54.999727      INFO        NSE_VEDL
# 705         706  2024-08-29 15:26:54.999727      INFO      NSE_VOLTAS
# 706         707  2024-08-29 15:26:54.999727      INFO       NSE_WIPRO
# 707         708  2024-08-29 15:26:54.999727      INFO   NSE_ZYDUSLIFE
#
#          mid    weight  is_constituent  vol_ratio  vol_ratio_index  \
# 0        0.0  0.000000              -1   0.000000         0.039607
# 1        0.0  0.000000              -1   0.000000         0.039607
# 2        0.0  0.000000              -1   0.000000         0.039607
# 3        0.0  0.000000              -1   0.000000         0.039607
# 4        0.0  0.000000              -1   0.000000         0.039607
# ..       ...       ...             ...        ...              ...
# 703      0.0  0.000000              -1   0.000000         0.017522
# 704      0.0  0.000000              -1   0.000000         0.017522
# 705      0.0  0.000000              -1   0.000000         0.017522
# 706  54082.5  0.319495               1   0.008279         0.017522
# 707      0.0  0.000000              -1   0.000000         0.017522
#
#      vol_ratio_constituents  ...  return.10000  return.30000  return.60000  \
# 0                  0.020531  ...        0.0205        0.0230        0.0914
# 1                  0.020531  ...        0.0000        0.0000        0.0498
# 2                  0.020531  ...        0.0319        0.0820        0.0273
# 3                  0.020531  ...       -0.0080        0.0080        0.2172
# 4                  0.020531  ...        0.0794        0.1544        0.1207
# ..                      ...  ...           ...           ...           ...
# 703                0.010578  ...       -0.0174        0.0131       -0.0696
# 704                0.010578  ...        0.0650        0.1354        0.1409
# 705                0.010578  ...        0.0367        0.0876        0.0622
# 706                0.010578  ...        0.0463       -0.1667       -0.1575
# 707                0.010578  ...        0.0044        0.0022        0.0222
#
#      return.300000  return.600000  return.900000  return.1800000  time_only  \
# 0           0.1620         0.5420         0.5318          0.7872   15:23:49
# 1           0.0446         0.1588         0.0338         -0.1935   15:23:49
# 2           0.1139         0.5239         0.3075          0.9135   15:23:49
# 3           0.4264         0.8850         0.6758          1.0539   15:23:49
# 4           0.3339         0.5797         0.4807          0.5003   15:23:49
# ..             ...            ...            ...             ...        ...
# 703        -0.0044         0.0653         0.1175          0.9269   15:26:54
# 704         0.4930         0.4442         0.3196          0.4334   15:26:54
# 705         0.4056         0.6190         0.9270          1.7552   15:26:54
# 706        -0.0278        -0.1760        -0.2501         -0.2177   15:26:54
# 707         0.1796         0.0998         0.2572          0.4568   15:26:54
#
#       date_only  lead_flag
# 0    2024-08-29          1
# 1    2024-08-29          1
# 2    2024-08-29          1
# 3    2024-08-29          1
# 4    2024-08-29          1
# ..          ...        ...
# 703  2024-08-29          1
# 704  2024-08-29          1
# 705  2024-08-29          1
# 706  2024-08-29          1
# 707  2024-08-29          1
#
# [708 rows x 31 columns]

# %%
# names diff than alpha for t = 15:23:49
x = u[u['time_only'] == '15:23:49']

for i in x.iterrows():
    if i[1]['ratio_diff'] * i[1]['return.600000'] < 0:
        print(i[1]['contract'], i[1]['ratio_diff'], i[1]['return.600000'], i[1]['vol_ratio'])
# Out:
# NSE_AUBANK 0.00165174 -0.2144 0.0
# NSE_CHOLAFIN 0.00165174 -0.0928 0.0
# NSE_COFORGE 0.00165174 -0.2725 0.0
# NSE_DIVISLAB 0.00165174 -0.0597 0.0462539
# NSE_GUJGASLTD 0.00165174 -0.0166 0.0
# NSE_HDFCAMC 0.00165174 -0.1257 0.0
# NSE_ICICIBANK 0.00165174 -0.0958 0.022244099999999996
# NSE_INDHOTEL 0.00165174 -0.1155 0.0
# NSE_INDIAMART 0.00165174 -0.4676 0.0
# NSE_JUBLFOOD 0.00165174 -0.0269 0.0
# NSE_LTTS 0.00165174 -0.1833 0.0
# NSE_MRF 0.00165174 -0.0205 0.0
# NSE_OFSS 0.00165174 -0.3567 0.0
# NSE_PAGEIND 0.00165174 -0.1344 0.0
# NSE_SBILIFE 0.00165174 -0.0865 0.028757599999999998
# NSE_TCS 0.00165174 -0.0403 0.0159165

# %%
x = u[u['time_only'] == '15:25:24']

for i in x.iterrows():
    if i[1]['ratio_diff'] * i[1]['return.600000'] < 0:
        print(i[1]['contract'], i[1]['ratio_diff'], i[1]['return.600000'], i[1]['vol_ratio'])
# Out:
# NSE_ABBOTINDIA 0.0017062999999999998 -0.0421 0.0
# NSE_APOLLOHOSP 0.0017062999999999998 -0.008 0.0416912
# NSE_AUBANK 0.0017062999999999998 -0.1287 0.0
# NSE_AXISBANK 0.0017062999999999998 -0.0531 0.028226599999999998
# NSE_BHARTIARTL 0.0017062999999999998 -0.0016 0.075986
# NSE_CHOLAFIN 0.0017062999999999998 -0.1236 0.0
# NSE_CIPLA 0.0017062999999999998 -0.1712 0.031165300000000003
# NSE_COFORGE 0.0017062999999999998 -0.1809 0.0
# NSE_COLPAL 0.0017062999999999998 -0.0104 0.0
# NSE_CUB 0.0017062999999999998 -0.0119 0.0
# NSE_DIVISLAB 0.0017062999999999998 -0.2804 0.0333865
# NSE_GUJGASLTD 0.0017062999999999998 -0.0083 0.0
# NSE_HINDUNILVR 0.0017062999999999998 -0.1377 0.030710900000000003
# NSE_ICICIBANK 0.0017062999999999998 -0.2869 0.0429714
# NSE_ICICIPRULI 0.0017062999999999998 -0.0101 0.0
# NSE_INDIAMART 0.0017062999999999998 -0.5408 0.0
# NSE_INFY 0.0017062999999999998 -0.0477 0.033828699999999996
# NSE_JUBLFOOD 0.0017062999999999998 -0.0346 0.0
# NSE_LT 0.0017062999999999998 -0.0163 0.015978799999999998
# NSE_LTTS 0.0017062999999999998 -0.0822 0.0
# NSE_MARICO 0.0017062999999999998 -0.2158 0.0
# NSE_MRF 0.0017062999999999998 -0.0185 0.0
# NSE_NAUKRI 0.0017062999999999998 -0.0309 0.0
# NSE_NESTLEIND 0.0017062999999999998 -0.0608 0.0330413
# NSE_OFSS 0.0017062999999999998 -0.387 0.0
# NSE_PAGEIND 0.0017062999999999998 -0.157 0.0
# NSE_SBILIFE 0.0017062999999999998 -0.1636 0.025748400000000005
# NSE_SUNPHARMA 0.0017062999999999998 -0.1992 0.0531361
# NSE_SYNGENE 0.0017062999999999998 -0.1023 0.0
# NSE_TCS 0.0017062999999999998 -0.3882 0.0363697

# %%
x = u[u['time_only'] == '15:26:54']

for i in x.iterrows():
    if i[1]['ratio_diff'] * i[1]['return.600000'] < 0:
        print(i[1]['contract'], i[1]['ratio_diff'], i[1]['return.600000'], i[1]['vol_ratio'])
# Out:
# NSE_ALKEM 0.00179575 -0.1002 0.0
# NSE_APOLLOHOSP 0.00179575 -0.2605 0.0593214
# NSE_ASIANPAINT 0.00179575 -0.1434 0.0148404
# NSE_ATUL 0.00179575 -0.008 0.0
# NSE_AUBANK 0.00179575 -0.0468 0.0
# NSE_AXISBANK 0.00179575 -0.2145 0.0103191
# NSE_BAJAJFINSV 0.00179575 -0.3794 0.113798
# NSE_BAJFINANCE 0.00179575 -0.2041 0.012760500000000001
# NSE_BHARTIARTL 0.00179575 -0.1323 0.016915799999999998
# NSE_BSOFT 0.00179575 -0.1397 0.0
# NSE_CHOLAFIN 0.00179575 -0.1529 0.0
# NSE_CIPLA 0.00179575 -0.3649 0.021297999999999997
# NSE_COFORGE 0.00179575 -0.2367 0.0
# NSE_COLPAL 0.00179575 -0.1718 0.0
# NSE_DABUR 0.00179575 -0.1048 0.0
# NSE_DIVISLAB 0.00179575 -0.4129 0.08457780000000001
# NSE_DRREDDY 0.00179575 -0.2566 0.09575700000000001
# NSE_GUJGASLTD 0.00179575 -0.0871 0.0
# NSE_HDFCLIFE 0.00179575 -0.4693 0.00880406
# NSE_HINDUNILVR 0.00179575 -0.4737 0.0128585
# NSE_ICICIBANK 0.00179575 -0.5328 0.029466200000000005
# NSE_ICICIPRULI 0.00179575 -0.2289 0.0
# NSE_INDIAMART 0.00179575 -0.6243 0.0
# NSE_INDUSINDBK 0.00179575 -0.0917 0.0518921
# NSE_INFY 0.00179575 -0.3963 0.012851499999999998
# NSE_ITC 0.00179575 -0.4189 0.024278099999999997
# NSE_JSWSTEEL 0.00179575 -0.1354 0.0165576
# NSE_JUBLFOOD 0.00179575 -0.1651 0.0
# NSE_KOTAKBANK 0.00179575 -0.1039 0.027368
# NSE_LT 0.00179575 -0.2199 0.0126417
# NSE_LTIM 0.00179575 -0.2925 0.0217353
# NSE_LTTS 0.00179575 -0.0705 0.0
# NSE_M&M 0.00179575 -0.1756 0.021515
# NSE_MARICO 0.00179575 -0.3404 0.0
# NSE_MFSL 0.00179575 -0.3491 0.0
# NSE_MRF 0.00179575 -0.0691 0.0
# NSE_NAUKRI 0.00179575 -0.0274 0.0
# NSE_NESTLEIND 0.00179575 -0.3067 0.0365295
# NSE_OFSS 0.00179575 -0.4073 0.0
# NSE_POWERGRID 0.00179575 -0.1201 0.0177689
# NSE_SBILIFE 0.00179575 -0.3355 0.0191368
# NSE_SHRIRAMFIN 0.00179575 -0.1163 0.0478696
# NSE_SUNPHARMA 0.00179575 -0.3402 0.020189099999999998
# NSE_SYNGENE 0.00179575 -0.2018 0.0
# NSE_TATACONSUM 0.00179575 -0.3391 0.0465757
# NSE_TCS 0.00179575 -0.6369 0.0337412
# NSE_TECHM 0.00179575 -0.1889 0.0219694
# NSE_TITAN 0.00179575 -0.4659 0.0125202
# NSE_TORNTPHARM 0.00179575 -0.0933 0.0
# NSE_WIPRO 0.00179575 -0.17600000000000002 0.00827853
